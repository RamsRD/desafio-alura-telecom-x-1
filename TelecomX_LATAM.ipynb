# %% [markdown]
# <a href="https://colab.research.google.com/github/RamsRD/desafio-alura-telecom-x-1/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Desafío Telecom X LATAM 1**

# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ##Importación de datos

# %%
#Importamos la biblioteca de pandas para manipulación de datos
import pandas as pd

#Mostrar todas las columnas,sin truncarlas
pd.set_option('display.max_columns', None)

#Mostrar todas las filas, sin truncarlas
pd.set_option('display.max_rows', None)

# %%
#URLs del archivo .json con los datos de Telecom X
url1 = "https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/main/TelecomX_Data.json"

#Leyendo los archivos .json y almacenando los datos en un DataFrame
datos = pd.read_json(url1)

# %% [markdown]
# ##Analizando los datos

# %%
#Viendo el tamaño de los datos
datos.shape
# Out:
# (7267, 6)

# %%
#Viendo los primeros 6 datos
datos.head(6)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
#Viendo los metadatos de los datos
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##Transformando los datos del DataFrame

# %%
#1. Aplanar columnas anidadas y crear nuevos DataFrames usando pd_json_normalize
df_customer = pd.json_normalize(datos['customer'])
df_phone = pd.json_normalize(datos['phone'])
df_internet = pd.json_normalize(datos['internet'])
df_account = pd.json_normalize(datos['account'])

#2. Unir todas las columnas usando pd.concat en un solo DataFrame; eliminando columnas originales para evitar duplicados
datos_transformados = pd.concat(
    [
        datos.drop(columns=['customer', 'phone', 'internet', 'account']),
        df_customer,
        df_phone,
        df_internet,
        df_account
    ],
    axis=1
)

#3. Renombrar columnas para evitar caracteres especiales y lograr consistencia
datos_transformados.columns = datos_transformados.columns.str.replace('.', '_', regex=False)

#4. Convertir columnas numéricas que puedan estar como texto
datos_transformados['Charges_Monthly'] = pd.to_numeric(datos_transformados['Charges_Monthly'], errors='coerce')
datos_transformados['Charges_Total'] = pd.to_numeric(datos_transformados['Charges_Total'], errors='coerce')

#5. Imprimir los resultados para ver cómo quedó
print(datos_transformados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges_Monthly   7267 non-null   float64
#  20  Charges_Total     7256 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB
# None

# %% [markdown]
# ##Revisando los cambios

# %%
#Viendo las primeras 6 filas de los datos
datos_transformados.head(6)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
# 5  0013-MHZWF    No  Female              0      No        Yes       9
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          Yes            No             DSL             No          Yes
# 1          Yes           Yes             DSL             No           No
# 2          Yes            No     Fiber optic             No           No
# 3          Yes            No     Fiber optic             No          Yes
# 4          Yes            No     Fiber optic             No           No
# 5          Yes            No             DSL             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
# 5               No         Yes         Yes             Yes  Month-to-month
#
#   PaperlessBilling            PaymentMethod  Charges_Monthly  Charges_Total
# 0              Yes             Mailed check             65.6         593.30
# 1               No             Mailed check             59.9         542.40
# 2              Yes         Electronic check             73.9         280.85
# 3              Yes         Electronic check             98.0        1237.85
# 4              Yes             Mailed check             83.9         267.40
# 5              Yes  Credit card (automatic)             69.4         571.45

# %%
#Revisar valores faltantes
print("Valores nulos por columna:")
print(datos_transformados.isnull().sum())
# Out:
# Valores nulos por columna:
# customerID           0
# Churn                0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# Charges_Monthly      0
# Charges_Total       11
# dtype: int64

# %% [markdown]
# ##Comprobación de los datos y manejo de inconsistencias

# %%
#1. Buscar duplicados por customerID
duplicados = datos_transformados.duplicated(subset='customerID').sum()
print(f"Duplicados encontrados: {duplicados}")

#2. Estandarizar texto: todo en minúsculas para variables categóricas
columnas_objeto = datos_transformados.select_dtypes(include='object').columns
datos_transformados[columnas_objeto] = datos_transformados[columnas_objeto].apply(lambda x: x.str.strip().str.lower())

#3. Verificación final
datos_transformados.head(6)
# Out:
# Duplicados encontrados: 0
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-orfbo    no  female              0     yes        yes       9
# 1  0003-mknfe    no    male              0      no         no       9
# 2  0004-tlhlj   yes    male              0      no         no       4
# 3  0011-igkff   yes    male              1     yes         no      13
# 4  0013-exchz   yes  female              1     yes         no       3
# 5  0013-mhzwf    no  female              0      no        yes       9
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          yes            no             dsl             no          yes
# 1          yes           yes             dsl             no           no
# 2          yes            no     fiber optic             no           no
# 3          yes            no     fiber optic             no          yes
# 4          yes            no     fiber optic             no           no
# 5          yes            no             dsl             no           no
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               no         yes         yes              no        one year
# 1               no          no          no             yes  month-to-month
# 2              yes          no          no              no  month-to-month
# 3              yes          no         yes             yes  month-to-month
# 4               no         yes         yes              no  month-to-month
# 5               no         yes         yes             yes  month-to-month
#
#   PaperlessBilling            PaymentMethod  Charges_Monthly  Charges_Total
# 0              yes             mailed check             65.6         593.30
# 1               no             mailed check             59.9         542.40
# 2              yes         electronic check             73.9         280.85
# 3              yes         electronic check             98.0        1237.85
# 4              yes             mailed check             83.9         267.40
# 5              yes  credit card (automatic)             69.4         571.45

# %%
#1. Reemplazar valores nulos en Charges_Total por 0
datos_transformados['Charges_Total'] = datos_transformados['Charges_Total'].fillna(0)

#2. Eliminar duplicados por customerID
datos_transformados = datos_transformados.drop_duplicates(subset='customerID')

#3. Estandarizar variables categóricas (minúsculas y sin espacios)
columnas_objeto = datos_transformados.select_dtypes(include='object').columns
datos_transformados[columnas_objeto] = datos_transformados[columnas_objeto].apply(lambda x: x.str.strip().str.lower())

#4. Revisar resultados
datos_transformados.head(6)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-orfbo    no  female              0     yes        yes       9
# 1  0003-mknfe    no    male              0      no         no       9
# 2  0004-tlhlj   yes    male              0      no         no       4
# 3  0011-igkff   yes    male              1     yes         no      13
# 4  0013-exchz   yes  female              1     yes         no       3
# 5  0013-mhzwf    no  female              0      no        yes       9
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          yes            no             dsl             no          yes
# 1          yes           yes             dsl             no           no
# 2          yes            no     fiber optic             no           no
# 3          yes            no     fiber optic             no          yes
# 4          yes            no     fiber optic             no           no
# 5          yes            no             dsl             no           no
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               no         yes         yes              no        one year
# 1               no          no          no             yes  month-to-month
# 2              yes          no          no              no  month-to-month
# 3              yes          no         yes             yes  month-to-month
# 4               no         yes         yes              no  month-to-month
# 5               no         yes         yes             yes  month-to-month
#
#   PaperlessBilling            PaymentMethod  Charges_Monthly  Charges_Total
# 0              yes             mailed check             65.6         593.30
# 1               no             mailed check             59.9         542.40
# 2              yes         electronic check             73.9         280.85
# 3              yes         electronic check             98.0        1237.85
# 4              yes             mailed check             83.9         267.40
# 5              yes  credit card (automatic)             69.4         571.45

# %%
# Verificar tipos de datos y su consistencia
print(datos_transformados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges_Monthly   7267 non-null   float64
#  20  Charges_Total     7267 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB
# None

# %%
#Revisar si quedan valores nulos
print("\nValores nulos después de la limpieza:")
print(datos_transformados.isnull().sum())
# Out:
# Valores nulos después de la limpieza:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges_Monthly     0
# Charges_Total       0
# dtype: int64

# %% [markdown]
# ##Creación de la columna "cuentas diarias"

# %%
#1. Crear la columna Cuentas_Diarias a partir de Charges_Monthly
datos_transformados['Cuentas_Diarias'] = datos_transformados['Charges_Monthly'] / 30

#2. Redondear a 2 decimales para mejor claridad
datos_transformados['Cuentas_Diarias'] = datos_transformados['Cuentas_Diarias'].round(2)

#3. Verificación de los cambios
datos_transformados[['Charges_Monthly', 'Cuentas_Diarias']].head()
# Out:
#    Charges_Monthly  Cuentas_Diarias
# 0             65.6             2.19
# 1             59.9             2.00
# 2             73.9             2.46
# 3             98.0             3.27
# 4             83.9             2.80

# %% [markdown]
# ##Observando las variables de los datos de las columnas

# %%
#Observando las variables de los datos usando .unique
print(datos_transformados['customerID'].unique())
print(datos_transformados['Churn'].unique())
print(datos_transformados['gender'].unique())
print(datos_transformados['SeniorCitizen'].unique())
print(datos_transformados['Partner'].unique())
print(datos_transformados['Dependents'].unique())
print(datos_transformados['tenure'].unique())
# Out:
# ['0002-orfbo' '0003-mknfe' '0004-tlhlj' ... '9992-ujoel' '9993-lhieb'
#  '9995-hotoh']
# ['no' 'yes' '']
# ['female' 'male']
# [0 1]
# ['yes' 'no']
# ['yes' 'no']
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]

# %%
#Observando las variables de los datos usando .unique
print(datos_transformados['PhoneService'].unique())
print(datos_transformados['MultipleLines'].unique())
print(datos_transformados['InternetService'].unique())
print(datos_transformados['DeviceProtection'].unique())
print(datos_transformados['TechSupport'].unique())
# Out:
# ['yes' 'no']
# ['no' 'yes' 'no phone service']
# ['dsl' 'fiber optic' 'no']
# ['no' 'yes' 'no internet service']
# ['yes' 'no' 'no internet service']

# %%
#Observando las variables de los datos usando.unique
print(datos_transformados['OnlineSecurity'].unique)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 2268                    yes
# 2269                     no
# 2270                    yes
# 2271                     no
# 2272                    yes
# 2273    no internet service
# 2274                     no
# 2275    no internet service
# 2276                     no
# 2277                     no
# 2278                     no
# 2279    no internet service
# 2280                     no
# 2281                    yes
# 2282    no internet service
# 2283                     no
# 2284                    yes
# 2285                     no
# 2286    no internet service
# 2287    no internet service
# 2288                     no
# 2289                     no
# 2290                     no
# 2291                     no
# 2292                     no
# 2293    no internet service
# 2294                     no
# 2295                    yes
# 2296                     no
# 2297                     no
# 2298                    yes
# 2299                     no
# 2300                    yes
# 2301                     no
# 2302                     no
# 2303                     no
# 2304                     no
# 2305                     no
# 2306                     no
# 2307    no internet service
# 2308    no internet service
# 2309                    yes
# 2310                     no
# 2311                    yes
# 2312                     no
# 2313                     no
# 2314                     no
# 2315                    yes
# 2316                    yes
# 2317                    yes
# 2318                    yes
# 2319                    yes
# 2320                     no
# 2321                     no
# 2322                    yes
# 2323                     no
# 2324    no internet service
# 2325    no internet service
# 2326                    yes
# 2327                     no
# 2328    no internet service
# 2329                     no
# 2330                     no
# 2331                     no
# 2332    no internet service
# 2333                    yes
# 2334                     no
# 2335                     no
# 2336                     no
# 2337                     no
# 2338                    yes
# 2339                    yes
# 2340                     no
# 2341                     no
# 2342                    yes
# 2343    no internet service
# 2344                    yes
# 2345    no internet service
# 2346                     no
# 2347                     no
# 2348    no internet service
# 2349                     no
# 2350                     no
# 2351                     no
# 2352    no internet service
# 2353                     no
# 2354    no internet service
# 2355                     no
# 2356    no internet service
# 2357    no internet service
# 2358                     no
# 2359                     no
# 2360                     no
# 2361                     no
# 2362                    yes
# 2363                    yes
# 2364                    yes
# 2365                    yes
# 2366    no internet service
# 2367                    yes
# 2368    no internet service
# 2369                     no
# 2370                     no
# 2371                     no
# 2372                    yes
# 2373                     no
# 2374                    yes
# 2375                     no
# 2376                     no
# 2377    no internet service
# 2378                     no
# 2379                     no
# 2380                     no
# 2381                     no
# 2382                     no
# 2383                    yes
# 2384                    yes
# 2385                    yes
# 2386                     no
# 2387                    yes
# 2388                     no
# 2389                     no
# 2390    no internet service
# 2391                     no
# 2392                     no
# 2393                     no
# 2394                    yes
# 2395    no internet service
# 2396                     no
# 2397                     no
# 2398                     no
# 2399                    yes
# 2400                     no
# 2401                    yes
# 2402                    yes
# 2403                     no
# 2404    no internet service
# 2405                    yes
# 2406    no internet service
# 2407                    yes
# 2408    no internet service
# 2409                     no
# 2410                     no
# 2411                     no
# 2412    no internet service
# 2413                     no
# 2414    no internet service
# 2415    no internet service
# 2416                     no
# 2417    no internet service
# 2418                    yes
# 2419                     no
# 2420    no internet service
# 2421                     no
# 2422    no internet service
# 2423                     no
# 2424    no internet service
# 2425                     no
# 2426                     no
# 2427                     no
# 2428                     no
# 2429                     no
# 2430                    yes
# 2431                     no
# 2432                     no
# 2433                    yes
# 2434                     no
# 2435                    yes
# 2436                    yes
# 2437                    yes
# 2438                    yes
# 2439                     no
# 2440                    yes
# 2441    no internet service
# 2442                     no
# 2443                     no
# 2444                     no
# 2445                     no
# 2446                     no
# 2447                     no
# 2448                     no
# 2449                     no
# 2450                    yes
# 2451                     no
# 2452                     no
# 2453                     no
# 2454                     no
# 2455                    yes
# 2456    no internet service
# 2457                    yes
# 2458                     no
# 2459                     no
# 2460                     no
# 2461                     no
# 2462                    yes
# 2463                     no
# 2464                     no
# 2465                    yes
# 2466                    yes
# 2467                     no
# 2468                     no
# 2469                     no
# 2470                     no
# 2471    no internet service
# 2472                     no
# 2473    no internet service
# 2474                     no
# 2475                     no
# 2476                     no
# 2477    no internet service
# 2478    no internet service
# 2479    no internet service
# 2480    no internet service
# 2481                     no
# 2482                     no
# 2483                    yes
# 2484                    yes
# 2485                    yes
# 2486                     no
# 2487                    yes
# 2488                    yes
# 2489    no internet service
# 2490                     no
# 2491                     no
# 2492                     no
# 2493                    yes
# 2494                    yes
# 2495                    yes
# 2496    no internet service
# 2497    no internet service
# 2498                    yes
# 2499                     no
# 2500                     no
# 2501                    yes
# 2502                     no
# 2503                     no
# 2504    no internet service
# 2505                     no
# 2506                    yes
# 2507                     no
# 2508    no internet service
# 2509    no internet service
# 2510    no internet service
# 2511                    yes
# 2512                    yes
# 2513                     no
# 2514                    yes
# 2515                    yes
# 2516                    yes
# 2517                    yes
# 2518                     no
# 2519                     no
# 2520                    yes
# 2521    no internet service
# 2522                     no
# 2523                     no
# 2524                    yes
# 2525    no internet service
# 2526                     no
# 2527                     no
# 2528    no internet service
# 2529                     no
# 2530    no internet service
# 2531    no internet service
# 2532                    yes
# 2533                     no
# 2534                     no
# 2535                    yes
# 2536                     no
# 2537                    yes
# 2538                    yes
# 2539                    yes
# 2540                     no
# 2541    no internet service
# 2542    no internet service
# 2543    no internet service
# 2544                     no
# 2545                    yes
# 2546                     no
# 2547                     no
# 2548    no internet service
# 2549                    yes
# 2550                    yes
# 2551                     no
# 2552                     no
# 2553                     no
# 2554                     no
# 2555                     no
# 2556                    yes
# 2557                    yes
# 2558                    yes
# 2559                     no
# 2560                     no
# 2561                     no
# 2562                     no
# 2563    no internet service
# 2564                     no
# 2565    no internet service
# 2566                    yes
# 2567                     no
# 2568                     no
# 2569                     no
# 2570                    yes
# 2571                     no
# 2572                     no
# 2573                    yes
# 2574                    yes
# 2575                     no
# 2576                    yes
# 2577    no internet service
# 2578    no internet service
# 2579    no internet service
# 2580                    yes
# 2581                    yes
# 2582                     no
# 2583                     no
# 2584    no internet service
# 2585                     no
# 2586                    yes
# 2587                     no
# 2588                     no
# 2589                     no
# 2590    no internet service
# 2591                    yes
# 2592    no internet service
# 2593                    yes
# 2594                     no
# 2595                    yes
# 2596    no internet service
# 2597                     no
# 2598                    yes
# 2599                     no
# 2600                     no
# 2601                     no
# 2602                     no
# 2603    no internet service
# 2604                     no
# 2605                    yes
# 2606                     no
# 2607                    yes
# 2608                     no
# 2609                     no
# 2610    no internet service
# 2611                    yes
# 2612                     no
# 2613                    yes
# 2614                     no
# 2615    no internet service
# 2616    no internet service
# 2617                     no
# 2618                     no
# 2619                     no
# 2620    no internet service
# 2621                     no
# 2622                    yes
# 2623                    yes
# 2624                    yes
# 2625                    yes
# 2626                    yes
# 2627                    yes
# 2628    no internet service
# 2629                     no
# 2630                     no
# 2631                    yes
# 2632                     no
# 2633                     no
# 2634                    yes
# 2635                     no
# 2636                     no
# 2637    no internet service
# 2638    no internet service
# 2639                     no
# 2640                     no
# 2641    no internet service
# 2642    no internet service
# 2643                    yes
# 2644    no internet service
# 2645    no internet service
# 2646                     no
# 2647                     no
# 2648                     no
# 2649                     no
# 2650                     no
# 2651                    yes
# 2652    no internet service
# 2653    no internet service
# 2654                    yes
# 2655                    yes
# 2656                     no
# 2657                    yes
# 2658                     no
# 2659                     no
# 2660    no internet service
# 2661                    yes
# 2662                     no
# 2663                     no
# 2664                     no
# 2665    no internet service
# 2666                    yes
# 2667                     no
# 2668                    yes
# 2669                     no
# 2670                     no
# 2671                     no
# 2672    no internet service
# 2673                    yes
# 2674                     no
# 2675    no internet service
# 2676    no internet service
# 2677                    yes
# 2678                     no
# 2679    no internet service
# 2680    no internet service
# 2681                     no
# 2682                     no
# 2683    no internet service
# 2684    no internet service
# 2685                    yes
# 2686    no internet service
# 2687    no internet service
# 2688                    yes
# 2689                     no
# 2690    no internet service
# 2691                    yes
# 2692                     no
# 2693                     no
# 2694                     no
# 2695                     no
# 2696                    yes
# 2697                     no
# 2698                    yes
# 2699                    yes
# 2700    no internet service
# 2701                     no
# 2702                     no
# 2703                     no
# 2704                     no
# 2705                     no
# 2706    no internet service
# 2707    no internet service
# 2708                     no
# 2709    no internet service
# 2710                     no
# 2711                     no
# 2712                     no
# 2713                    yes
# 2714                     no
# 2715                    yes
# 2716                     no
# 2717                     no
# 2718    no internet service
# 2719                     no
# 2720                    yes
# 2721                     no
# 2722    no internet service
# 2723    no internet service
# 2724                     no
# 2725    no internet service
# 2726                     no
# 2727                     no
# 2728    no internet service
# 2729    no internet service
# 2730                    yes
# 2731                     no
# 2732                     no
# 2733                     no
# 2734    no internet service
# 2735    no internet service
# 2736                    yes
# 2737                     no
# 2738                     no
# 2739                     no
# 2740                     no
# 2741                    yes
# 2742                    yes
# 2743                     no
# 2744                     no
# 2745                     no
# 2746                     no
# 2747                     no
# 2748                    yes
# 2749                     no
# 2750    no internet service
# 2751                    yes
# 2752                     no
# 2753                    yes
# 2754    no internet service
# 2755                    yes
# 2756    no internet service
# 2757                     no
# 2758                    yes
# 2759    no internet service
# 2760                     no
# 2761    no internet service
# 2762                    yes
# 2763                     no
# 2764                    yes
# 2765    no internet service
# 2766    no internet service
# 2767                    yes
# 2768                     no
# 2769    no internet service
# 2770                     no
# 2771                     no
# 2772                    yes
# 2773                     no
# 2774                    yes
# 2775    no internet service
# 2776                     no
# 2777    no internet service
# 2778                    yes
# 2779                     no
# 2780                     no
# 2781                     no
# 2782                    yes
# 2783                     no
# 2784                     no
# 2785                     no
# 2786                    yes
# 2787                    yes
# 2788    no internet service
# 2789                    yes
# 2790                    yes
# 2791                     no
# 2792                    yes
# 2793                     no
# 2794                     no
# 2795    no internet service
# 2796                     no
# 2797                     no
# 2798                     no
# 2799                    yes
# 2800                     no
# 2801                    yes
# 2802                     no
# 2803    no internet service
# 2804                    yes
# 2805                     no
# 2806                    yes
# 2807                     no
# 2808                    yes
# 2809                     no
# 2810                     no
# 2811    no internet service
# 2812                    yes
# 2813                    yes
# 2814    no internet service
# 2815                     no
# 2816                    yes
# 2817                    yes
# 2818                     no
# 2819                    yes
# 2820    no internet service
# 2821                     no
# 2822                    yes
# 2823    no internet service
# 2824                     no
# 2825                    yes
# 2826                     no
# 2827                     no
# 2828                     no
# 2829                     no
# 2830                     no
# 2831                     no
# 2832    no internet service
# 2833                     no
# 2834                     no
# 2835                     no
# 2836                    yes
# 2837    no internet service
# 2838    no internet service
# 2839                    yes
# 2840                     no
# 2841                     no
# 2842                     no
# 2843                     no
# 2844                     no
# 2845                     no
# 2846                    yes
# 2847                    yes
# 2848                    yes
# 2849                     no
# 2850                     no
# 2851                    yes
# 2852                     no
# 2853                    yes
# 2854                     no
# 2855    no internet service
# 2856                     no
# 2857                    yes
# 2858                     no
# 2859                    yes
# 2860    no internet service
# 2861                    yes
# 2862                    yes
# 2863    no internet service
# 2864    no internet service
# 2865                     no
# 2866    no internet service
# 2867    no internet service
# 2868    no internet service
# 2869    no internet service
# 2870    no internet service
# 2871                    yes
# 2872    no internet service
# 2873                     no
# 2874    no internet service
# 2875                    yes
# 2876                     no
# 2877                     no
# 2878                     no
# 2879                     no
# 2880                     no
# 2881    no internet service
# 2882                     no
# 2883                     no
# 2884                     no
# 2885                     no
# 2886                    yes
# 2887                     no
# 2888                    yes
# 2889                    yes
# 2890                    yes
# 2891                     no
# 2892                    yes
# 2893                    yes
# 2894                    yes
# 2895                     no
# 2896    no internet service
# 2897                     no
# 2898                     no
# 2899                     no
# 2900    no internet service
# 2901    no internet service
# 2902    no internet service
# 2903                     no
# 2904                    yes
# 2905                    yes
# 2906                     no
# 2907                     no
# 2908                     no
# 2909                    yes
# 2910                     no
# 2911                     no
# 2912                     no
# 2913    no internet service
# 2914                    yes
# 2915    no internet service
# 2916                    yes
# 2917                     no
# 2918                     no
# 2919                     no
# 2920                     no
# 2921                     no
# 2922                     no
# 2923    no internet service
# 2924                     no
# 2925                     no
# 2926                     no
# 2927                    yes
# 2928                     no
# 2929                    yes
# 2930                     no
# 2931                     no
# 2932                    yes
# 2933                     no
# 2934    no internet service
# 2935                     no
# 2936                    yes
# 2937                    yes
# 2938                    yes
# 2939                     no
# 2940                    yes
# 2941    no internet service
# 2942                    yes
# 2943    no internet service
# 2944                     no
# 2945    no internet service
# 2946                     no
# 2947                     no
# 2948                    yes
# 2949    no internet service
# 2950                     no
# 2951                    yes
# 2952                     no
# 2953    no internet service
# 2954                    yes
# 2955                     no
# 2956                    yes
# 2957                    yes
# 2958                     no
# 2959                     no
# 2960                     no
# 2961                     no
# 2962                    yes
# 2963                     no
# 2964                     no
# 2965                     no
# 2966    no internet service
# 2967                    yes
# 2968                    yes
# 2969                     no
# 2970    no internet service
# 2971                    yes
# 2972                     no
# 2973    no internet service
# 2974                     no
# 2975                     no
# 2976                     no
# 2977                     no
# 2978                     no
# 2979                    yes
# 2980                    yes
# 2981                    yes
# 2982                    yes
# 2983                     no
# 2984                     no
# 2985                    yes
# 2986                    yes
# 2987                    yes
# 2988                     no
# 2989                     no
# 2990    no internet service
# 2991                     no
# 2992                     no
# 2993                     no
# 2994                     no
# 2995                     no
# 2996                     no
# 2997    no internet service
# 2998    no internet service
# 2999    no internet service
# 3000    no internet service
# 3001                     no
# 3002                    yes
# 3003    no internet service
# 3004                     no
# 3005                    yes
# 3006    no internet service
# 3007                     no
# 3008                     no
# 3009                    yes
# 3010                     no
# 3011                     no
# 3012                     no
# 3013                    yes
# 3014                    yes
# 3015                     no
# 3016                     no
# 3017                     no
# 3018                     no
# 3019    no internet service
# 3020                     no
# 3021                    yes
# 3022                     no
# 3023                     no
# 3024    no internet service
# 3025    no internet service
# 3026                    yes
# 3027                     no
# 3028                    yes
# 3029    no internet service
# 3030                     no
# 3031                     no
# 3032    no internet service
# 3033    no internet service
# 3034                     no
# 3035                    yes
# 3036                     no
# 3037                     no
# 3038                    yes
# 3039                     no
# 3040                     no
# 3041    no internet service
# 3042    no internet service
# 3043                     no
# 3044                     no
# 3045                     no
# 3046    no internet service
# 3047                     no
# 3048                     no
# 3049                     no
# 3050                     no
# 3051                    yes
# 3052                    yes
# 3053    no internet service
# 3054                    yes
# 3055                     no
# 3056                    yes
# 3057    no internet service
# 3058                     no
# 3059                     no
# 3060    no internet service
# 3061                     no
# 3062                     no
# 3063                     no
# 3064    no internet service
# 3065                     no
# 3066                    yes
# 3067                     no
# 3068                     no
# 3069                    yes
# 3070                     no
# 3071                     no
# 3072                    yes
# 3073                     no
# 3074                     no
# 3075                     no
# 3076                     no
# 3077    no internet service
# 3078                     no
# 3079                     no
# 3080                    yes
# 3081    no internet service
# 3082                     no
# 3083                    yes
# 3084                     no
# 3085    no internet service
# 3086                    yes
# 3087                     no
# 3088    no internet service
# 3089                    yes
# 3090                    yes
# 3091                    yes
# 3092                     no
# 3093                     no
# 3094    no internet service
# 3095                    yes
# 3096    no internet service
# 3097                    yes
# 3098                    yes
# 3099                     no
# 3100    no internet service
# 3101                     no
# 3102                     no
# 3103    no internet service
# 3104                     no
# 3105                    yes
# 3106                    yes
# 3107                     no
# 3108                    yes
# 3109                     no
# 3110                    yes
# 3111                    yes
# 3112                    yes
# 3113    no internet service
# 3114    no internet service
# 3115                     no
# 3116                     no
# 3117                    yes
# 3118                    yes
# 3119                     no
# 3120                     no
# 3121                     no
# 3122                     no
# 3123                     no
# 3124                    yes
# 3125    no internet service
# 3126                     no
# 3127                     no
# 3128                    yes
# 3129    no internet service
# 3130                     no
# 3131    no internet service
# 3132                     no
# 3133                     no
# 3134    no internet service
# 3135                    yes
# 3136                     no
# 3137                     no
# 3138                     no
# 3139                    yes
# 3140                    yes
# 3141                    yes
# 3142    no internet service
# 3143                    yes
# 3144                    yes
# 3145                     no
# 3146                     no
# 3147                    yes
# 3148    no internet service
# 3149                     no
# 3150                     no
# 3151                    yes
# 3152    no internet service
# 3153                    yes
# 3154                     no
# 3155    no internet service
# 3156    no internet service
# 3157                     no
# 3158                    yes
# 3159    no internet service
# 3160                    yes
# 3161                     no
# 3162                     no
# 3163                    yes
# 3164                     no
# 3165                     no
# 3166                     no
# 3167                     no
# 3168                    yes
# 3169                     no
# 3170    no internet service
# 3171                     no
# 3172                     no
# 3173    no internet service
# 3174                    yes
# 3175                     no
# 3176                     no
# 3177                    yes
# 3178                     no
# 3179                     no
# 3180                     no
# 3181    no internet service
# 3182                    yes
# 3183                     no
# 3184                     no
# 3185                     no
# 3186                     no
# 3187                     no
# 3188    no internet service
# 3189                     no
# 3190    no internet service
# 3191                     no
# 3192                     no
# 3193    no internet service
# 3194                     no
# 3195                     no
# 3196    no internet service
# 3197                     no
# 3198                     no
# 3199                     no
# 3200                     no
# 3201                     no
# 3202                     no
# 3203                    yes
# 3204                    yes
# 3205    no internet service
# 3206                    yes
# 3207                     no
# 3208                     no
# 3209                     no
# 3210                     no
# 3211                     no
# 3212                     no
# 3213                     no
# 3214    no internet service
# 3215    no internet service
# 3216                     no
# 3217    no internet service
# 3218                    yes
# 3219                    yes
# 3220                    yes
# 3221                     no
# 3222                     no
# 3223                     no
# 3224                     no
# 3225                     no
# 3226                    yes
# 3227                     no
# 3228                    yes
# 3229                     no
# 3230                    yes
# 3231                     no
# 3232                    yes
# 3233                     no
# 3234    no internet service
# 3235    no internet service
# 3236                     no
# 3237                     no
# 3238                    yes
# 3239                     no
# 3240                    yes
# 3241                    yes
# 3242    no internet service
# 3243                    yes
# 3244                     no
# 3245                     no
# 3246    no internet service
# 3247                    yes
# 3248    no internet service
# 3249                     no
# 3250                     no
# 3251    no internet service
# 3252                     no
# 3253    no internet service
# 3254    no internet service
# 3255                     no
# 3256                     no
# 3257                    yes
# 3258                     no
# 3259                     no
# 3260                     no
# 3261                    yes
# 3262                     no
# 3263                     no
# 3264                     no
# 3265                     no
# 3266                    yes
# 3267    no internet service
# 3268                    yes
# 3269                     no
# 3270                    yes
# 3271                    yes
# 3272    no internet service
# 3273                     no
# 3274                     no
# 3275                     no
# 3276                     no
# 3277                    yes
# 3278    no internet service
# 3279                     no
# 3280                     no
# 3281    no internet service
# 3282                     no
# 3283                     no
# 3284                     no
# 3285                     no
# 3286                     no
# 3287                     no
# 3288    no internet service
# 3289                     no
# 3290                     no
# 3291                    yes
# 3292                     no
# 3293    no internet service
# 3294    no internet service
# 3295                    yes
# 3296    no internet service
# 3297                     no
# 3298                     no
# 3299                    yes
# 3300                    yes
# 3301                     no
# 3302                     no
# 3303                     no
# 3304    no internet service
# 3305                    yes
# 3306                    yes
# 3307                     no
# 3308                     no
# 3309                     no
# 3310                     no
# 3311    no internet service
# 3312                     no
# 3313                     no
# 3314                    yes
# 3315    no internet service
# 3316                    yes
# 3317    no internet service
# 3318    no internet service
# 3319                     no
# 3320                     no
# 3321                     no
# 3322                    yes
# 3323                     no
# 3324                     no
# 3325                     no
# 3326                     no
# 3327    no internet service
# 3328                    yes
# 3329                     no
# 3330    no internet service
# 3331    no internet service
# 3332                     no
# 3333                     no
# 3334                     no
# 3335    no internet service
# 3336                     no
# 3337    no internet service
# 3338    no internet service
# 3339                    yes
# 3340                    yes
# 3341                     no
# 3342                     no
# 3343                     no
# 3344                     no
# 3345    no internet service
# 3346                    yes
# 3347                    yes
# 3348                    yes
# 3349    no internet service
# 3350                     no
# 3351                     no
# 3352                    yes
# 3353                    yes
# 3354    no internet service
# 3355                     no
# 3356                    yes
# 3357    no internet service
# 3358                    yes
# 3359                     no
# 3360                     no
# 3361                    yes
# 3362                    yes
# 3363                    yes
# 3364                    yes
# 3365                     no
# 3366                    yes
# 3367                    yes
# 3368                     no
# 3369                    yes
# 3370                     no
# 3371                     no
# 3372                     no
# 3373    no internet service
# 3374                     no
# 3375                     no
# 3376                     no
# 3377                     no
# 3378                     no
# 3379                     no
# 3380    no internet service
# 3381    no internet service
# 3382                     no
# 3383                     no
# 3384    no internet service
# 3385    no internet service
# 3386                    yes
# 3387                     no
# 3388                    yes
# 3389                     no
# 3390                    yes
# 3391                     no
# 3392    no internet service
# 3393                     no
# 3394                     no
# 3395                     no
# 3396    no internet service
# 3397    no internet service
# 3398    no internet service
# 3399                     no
# 3400                    yes
# 3401                    yes
# 3402    no internet service
# 3403                     no
# 3404                     no
# 3405                     no
# 3406    no internet service
# 3407                     no
# 3408                     no
# 3409                    yes
# 3410    no internet service
# 3411                     no
# 3412                    yes
# 3413                    yes
# 3414                    yes
# 3415                     no
# 3416                     no
# 3417                    yes
# 3418    no internet service
# 3419                     no
# 3420    no internet service
# 3421                    yes
# 3422                     no
# 3423                    yes
# 3424                    yes
# 3425    no internet service
# 3426    no internet service
# 3427                    yes
# 3428                     no
# 3429                     no
# 3430    no internet service
# 3431                     no
# 3432                     no
# 3433                     no
# 3434                     no
# 3435                     no
# 3436                    yes
# 3437    no internet service
# 3438                     no
# 3439                     no
# 3440                    yes
# 3441                     no
# 3442    no internet service
# 3443                     no
# 3444    no internet service
# 3445                     no
# 3446                    yes
# 3447    no internet service
# 3448    no internet service
# 3449                    yes
# 3450    no internet service
# 3451    no internet service
# 3452                     no
# 3453    no internet service
# 3454                    yes
# 3455                     no
# 3456                     no
# 3457    no internet service
# 3458                    yes
# 3459                    yes
# 3460    no internet service
# 3461                    yes
# 3462    no internet service
# 3463                    yes
# 3464    no internet service
# 3465                     no
# 3466    no internet service
# 3467    no internet service
# 3468                     no
# 3469                    yes
# 3470                     no
# 3471                     no
# 3472    no internet service
# 3473                    yes
# 3474                     no
# 3475                     no
# 3476                     no
# 3477    no internet service
# 3478                    yes
# 3479                     no
# 3480                     no
# 3481                     no
# 3482    no internet service
# 3483                     no
# 3484                     no
# 3485                     no
# 3486                    yes
# 3487                     no
# 3488                    yes
# 3489    no internet service
# 3490                     no
# 3491                     no
# 3492                     no
# 3493                     no
# 3494                    yes
# 3495    no internet service
# 3496                    yes
# 3497                     no
# 3498                     no
# 3499                     no
# 3500                    yes
# 3501                    yes
# 3502                     no
# 3503                     no
# 3504                     no
# 3505                    yes
# 3506    no internet service
# 3507                    yes
# 3508                     no
# 3509                    yes
# 3510                     no
# 3511    no internet service
# 3512                    yes
# 3513                    yes
# 3514                     no
# 3515                     no
# 3516                     no
# 3517                     no
# 3518                     no
# 3519                    yes
# 3520                     no
# 3521                    yes
# 3522                    yes
# 3523                     no
# 3524                    yes
# 3525                     no
# 3526                     no
# 3527                    yes
# 3528    no internet service
# 3529                    yes
# 3530                     no
# 3531                     no
# 3532                    yes
# 3533                    yes
# 3534                     no
# 3535    no internet service
# 3536                    yes
# 3537    no internet service
# 3538    no internet service
# 3539                     no
# 3540    no internet service
# 3541                     no
# 3542    no internet service
# 3543                     no
# 3544    no internet service
# 3545                    yes
# 3546                     no
# 3547                    yes
# 3548                     no
# 3549    no internet service
# 3550    no internet service
# 3551    no internet service
# 3552    no internet service
# 3553    no internet service
# 3554                    yes
# 3555                     no
# 3556                     no
# 3557    no internet service
# 3558                     no
# 3559                     no
# 3560                     no
# 3561                     no
# 3562                     no
# 3563                     no
# 3564                     no
# 3565                     no
# 3566                    yes
# 3567                    yes
# 3568                     no
# 3569                     no
# 3570                    yes
# 3571                     no
# 3572                     no
# 3573                     no
# 3574                     no
# 3575                     no
# 3576                     no
# 3577                     no
# 3578                    yes
# 3579                     no
# 3580                    yes
# 3581    no internet service
# 3582    no internet service
# 3583    no internet service
# 3584                     no
# 3585                     no
# 3586                    yes
# 3587                    yes
# 3588                     no
# 3589    no internet service
# 3590                    yes
# 3591                     no
# 3592                     no
# 3593                     no
# 3594    no internet service
# 3595                     no
# 3596                     no
# 3597    no internet service
# 3598    no internet service
# 3599                    yes
# 3600                    yes
# 3601                     no
# 3602                     no
# 3603                     no
# 3604    no internet service
# 3605                    yes
# 3606                     no
# 3607                    yes
# 3608                    yes
# 3609                     no
# 3610    no internet service
# 3611    no internet service
# 3612                    yes
# 3613                     no
# 3614                     no
# 3615    no internet service
# 3616                     no
# 3617                    yes
# 3618                     no
# 3619                     no
# 3620                     no
# 3621    no internet service
# 3622                    yes
# 3623                     no
# 3624                    yes
# 3625                     no
# 3626                     no
# 3627                    yes
# 3628    no internet service
# 3629                     no
# 3630    no internet service
# 3631                    yes
# 3632                     no
# 3633                    yes
# 3634    no internet service
# 3635                    yes
# 3636                     no
# 3637                     no
# 3638    no internet service
# 3639                     no
# 3640    no internet service
# 3641                    yes
# 3642                     no
# 3643                    yes
# 3644                     no
# 3645                     no
# 3646    no internet service
# 3647                     no
# 3648                     no
# 3649                    yes
# 3650                     no
# 3651    no internet service
# 3652                     no
# 3653                    yes
# 3654                     no
# 3655                     no
# 3656                    yes
# 3657    no internet service
# 3658                     no
# 3659                     no
# 3660    no internet service
# 3661                    yes
# 3662                     no
# 3663    no internet service
# 3664                    yes
# 3665                     no
# 3666                     no
# 3667                    yes
# 3668                    yes
# 3669                    yes
# 3670                     no
# 3671    no internet service
# 3672                     no
# 3673                    yes
# 3674                     no
# 3675    no internet service
# 3676    no internet service
# 3677    no internet service
# 3678                    yes
# 3679                     no
# 3680                    yes
# 3681                    yes
# 3682                     no
# 3683                     no
# 3684    no internet service
# 3685                     no
# 3686                     no
# 3687                     no
# 3688                    yes
# 3689                    yes
# 3690                     no
# 3691    no internet service
# 3692                    yes
# 3693                     no
# 3694                    yes
# 3695                    yes
# 3696    no internet service
# 3697                     no
# 3698                    yes
# 3699                     no
# 3700                     no
# 3701                    yes
# 3702                    yes
# 3703                    yes
# 3704    no internet service
# 3705                     no
# 3706                    yes
# 3707                     no
# 3708                     no
# 3709                     no
# 3710                     no
# 3711                     no
# 3712    no internet service
# 3713                    yes
# 3714                     no
# 3715                    yes
# 3716                    yes
# 3717                    yes
# 3718                     no
# 3719                    yes
# 3720                     no
# 3721                     no
# 3722                    yes
# 3723                     no
# 3724    no internet service
# 3725                    yes
# 3726                    yes
# 3727                     no
# 3728                    yes
# 3729                     no
# 3730                    yes
# 3731                    yes
# 3732                    yes
# 3733                     no
# 3734    no internet service
# 3735    no internet service
# 3736                     no
# 3737                     no
# 3738    no internet service
# 3739    no internet service
# 3740                    yes
# 3741                     no
# 3742                    yes
# 3743                     no
# 3744                     no
# 3745                    yes
# 3746                    yes
# 3747                    yes
# 3748                     no
# 3749                    yes
# 3750                     no
# 3751                     no
# 3752    no internet service
# 3753                     no
# 3754                     no
# 3755                    yes
# 3756                     no
# 3757                     no
# 3758                     no
# 3759                     no
# 3760                     no
# 3761                    yes
# 3762    no internet service
# 3763                     no
# 3764                    yes
# 3765                     no
# 3766    no internet service
# 3767                     no
# 3768                     no
# 3769                     no
# 3770                     no
# 3771                     no
# 3772    no internet service
# 3773                    yes
# 3774    no internet service
# 3775                     no
# 3776                    yes
# 3777                    yes
# 3778                    yes
# 3779                     no
# 3780                    yes
# 3781    no internet service
# 3782                     no
# 3783                     no
# 3784                     no
# 3785                     no
# 3786                    yes
# 3787                     no
# 3788                    yes
# 3789                     no
# 3790                    yes
# 3791    no internet service
# 3792                     no
# 3793                     no
# 3794                    yes
# 3795    no internet service
# 3796                    yes
# 3797                     no
# 3798                     no
# 3799                    yes
# 3800                    yes
# 3801                     no
# 3802                    yes
# 3803                     no
# 3804    no internet service
# 3805                    yes
# 3806                    yes
# 3807                     no
# 3808                     no
# 3809    no internet service
# 3810                     no
# 3811                     no
# 3812                     no
# 3813                     no
# 3814    no internet service
# 3815                     no
# 3816    no internet service
# 3817                    yes
# 3818                     no
# 3819                    yes
# 3820                     no
# 3821                     no
# 3822                     no
# 3823    no internet service
# 3824                     no
# 3825                     no
# 3826                     no
# 3827                     no
# 3828                    yes
# 3829                    yes
# 3830                    yes
# 3831                     no
# 3832    no internet service
# 3833                     no
# 3834                     no
# 3835                     no
# 3836                    yes
# 3837                    yes
# 3838                    yes
# 3839                    yes
# 3840    no internet service
# 3841                     no
# 3842    no internet service
# 3843                     no
# 3844                     no
# 3845    no internet service
# 3846                     no
# 3847                     no
# 3848                     no
# 3849                    yes
# 3850                    yes
# 3851                    yes
# 3852                     no
# 3853                     no
# 3854                     no
# 3855                     no
# 3856                    yes
# 3857                    yes
# 3858                     no
# 3859                     no
# 3860                    yes
# 3861                     no
# 3862                     no
# 3863                    yes
# 3864                     no
# 3865                     no
# 3866                    yes
# 3867    no internet service
# 3868    no internet service
# 3869                    yes
# 3870                    yes
# 3871                    yes
# 3872                     no
# 3873                     no
# 3874                     no
# 3875                     no
# 3876                     no
# 3877                     no
# 3878                    yes
# 3879                     no
# 3880    no internet service
# 3881                    yes
# 3882                     no
# 3883    no internet service
# 3884                     no
# 3885    no internet service
# 3886                     no
# 3887                    yes
# 3888                     no
# 3889                    yes
# 3890                    yes
# 3891                     no
# 3892                    yes
# 3893    no internet service
# 3894    no internet service
# 3895                    yes
# 3896                    yes
# 3897                     no
# 3898                     no
# 3899                     no
# 3900    no internet service
# 3901    no internet service
# 3902                    yes
# 3903                     no
# 3904                     no
# 3905                    yes
# 3906                    yes
# 3907                    yes
# 3908                     no
# 3909    no internet service
# 3910    no internet service
# 3911                     no
# 3912                     no
# 3913                     no
# 3914                     no
# 3915                    yes
# 3916                     no
# 3917    no internet service
# 3918    no internet service
# 3919                     no
# 3920                     no
# 3921                    yes
# 3922                     no
# 3923                     no
# 3924                     no
# 3925                     no
# 3926                     no
# 3927                     no
# 3928                     no
# 3929                    yes
# 3930    no internet service
# 3931                     no
# 3932                    yes
# 3933                     no
# 3934                     no
# 3935                    yes
# 3936                     no
# 3937                     no
# 3938                     no
# 3939    no internet service
# 3940                     no
# 3941                    yes
# 3942                     no
# 3943    no internet service
# 3944                    yes
# 3945                     no
# 3946                    yes
# 3947                     no
# 3948                     no
# 3949                    yes
# 3950                     no
# 3951                     no
# 3952                     no
# 3953    no internet service
# 3954                    yes
# 3955                     no
# 3956                     no
# 3957                     no
# 3958                     no
# 3959                     no
# 3960    no internet service
# 3961                     no
# 3962                     no
# 3963                     no
# 3964                     no
# 3965                     no
# 3966                     no
# 3967                     no
# 3968    no internet service
# 3969                     no
# 3970                    yes
# 3971                     no
# 3972                     no
# 3973                     no
# 3974                     no
# 3975                     no
# 3976    no internet service
# 3977    no internet service
# 3978                     no
# 3979                     no
# ...
# 6697                     no
# 6698                    yes
# 6699                    yes
# 6700                     no
# 6701    no internet service
# 6702                    yes
# 6703                    yes
# 6704    no internet service
# 6705                     no
# 6706                     no
# 6707                    yes
# 6708                     no
# 6709                    yes
# 6710                    yes
# 6711                     no
# 6712                    yes
# 6713                     no
# 6714                     no
# 6715                     no
# 6716                    yes
# 6717                     no
# 6718    no internet service
# 6719                    yes
# 6720                     no
# 6721                    yes
# 6722                     no
# 6723    no internet service
# 6724    no internet service
# 6725                    yes
# 6726                    yes
# 6727                     no
# 6728                     no
# 6729                     no
# 6730                     no
# 6731                     no
# 6732    no internet service
# 6733                    yes
# 6734                     no
# 6735                     no
# 6736                     no
# 6737                     no
# 6738                     no
# 6739                     no
# 6740                    yes
# 6741                     no
# 6742                     no
# 6743                     no
# 6744    no internet service
# 6745                    yes
# 6746                    yes
# 6747                    yes
# 6748                     no
# 6749                     no
# 6750                     no
# 6751                     no
# 6752                    yes
# 6753                     no
# 6754    no internet service
# 6755    no internet service
# 6756                     no
# 6757                     no
# 6758                     no
# 6759    no internet service
# 6760                    yes
# 6761                     no
# 6762                    yes
# 6763                    yes
# 6764                     no
# 6765                     no
# 6766                     no
# 6767    no internet service
# 6768                     no
# 6769                     no
# 6770    no internet service
# 6771                    yes
# 6772                     no
# 6773                     no
# 6774    no internet service
# 6775                    yes
# 6776                    yes
# 6777                     no
# 6778                    yes
# 6779                    yes
# 6780                    yes
# 6781                    yes
# 6782                    yes
# 6783                     no
# 6784    no internet service
# 6785                    yes
# 6786                     no
# 6787    no internet service
# 6788    no internet service
# 6789                     no
# 6790                     no
# 6791    no internet service
# 6792    no internet service
# 6793                     no
# 6794                     no
# 6795    no internet service
# 6796                     no
# 6797                    yes
# 6798                     no
# 6799    no internet service
# 6800                     no
# 6801                     no
# 6802                     no
# 6803    no internet service
# 6804                    yes
# 6805                    yes
# 6806                     no
# 6807                     no
# 6808                     no
# 6809                     no
# 6810                    yes
# 6811    no internet service
# 6812                     no
# 6813    no internet service
# 6814                     no
# 6815                     no
# 6816    no internet service
# 6817                     no
# 6818                     no
# 6819                     no
# 6820                     no
# 6821                    yes
# 6822                     no
# 6823                    yes
# 6824                     no
# 6825                    yes
# 6826                     no
# 6827                     no
# 6828                     no
# 6829                     no
# 6830                    yes
# 6831    no internet service
# 6832                     no
# 6833                    yes
# 6834    no internet service
# 6835    no internet service
# 6836                     no
# 6837    no internet service
# 6838                    yes
# 6839                     no
# 6840                    yes
# 6841                     no
# 6842    no internet service
# 6843    no internet service
# 6844                    yes
# 6845                     no
# 6846                     no
# 6847                     no
# 6848    no internet service
# 6849                     no
# 6850                     no
# 6851                     no
# 6852    no internet service
# 6853                    yes
# 6854                     no
# 6855                     no
# 6856                     no
# 6857    no internet service
# 6858                     no
# 6859                     no
# 6860                     no
# 6861                    yes
# 6862                    yes
# 6863                     no
# 6864                     no
# 6865                    yes
# 6866    no internet service
# 6867                     no
# 6868                    yes
# 6869                    yes
# 6870                     no
# 6871                    yes
# 6872    no internet service
# 6873                    yes
# 6874                     no
# 6875                     no
# 6876                    yes
# 6877                    yes
# 6878                    yes
# 6879                     no
# 6880                     no
# 6881                     no
# 6882                     no
# 6883                    yes
# 6884                     no
# 6885                    yes
# 6886                     no
# 6887    no internet service
# 6888                    yes
# 6889                    yes
# 6890                    yes
# 6891                     no
# 6892    no internet service
# 6893                     no
# 6894    no internet service
# 6895                    yes
# 6896    no internet service
# 6897                     no
# 6898                     no
# 6899                     no
# 6900    no internet service
# 6901                     no
# 6902    no internet service
# 6903    no internet service
# 6904                     no
# 6905                    yes
# 6906                     no
# 6907                    yes
# 6908                     no
# 6909                    yes
# 6910                     no
# 6911    no internet service
# 6912                     no
# 6913                     no
# 6914                    yes
# 6915                     no
# 6916                    yes
# 6917                    yes
# 6918                     no
# 6919                     no
# 6920    no internet service
# 6921    no internet service
# 6922    no internet service
# 6923                    yes
# 6924                     no
# 6925                     no
# 6926                    yes
# 6927                     no
# 6928                     no
# 6929    no internet service
# 6930                     no
# 6931    no internet service
# 6932                    yes
# 6933                     no
# 6934                    yes
# 6935                    yes
# 6936                    yes
# 6937                    yes
# 6938                    yes
# 6939                     no
# 6940                    yes
# 6941                     no
# 6942    no internet service
# 6943                     no
# 6944                    yes
# 6945                     no
# 6946                    yes
# 6947                     no
# 6948                    yes
# 6949                     no
# 6950    no internet service
# 6951                    yes
# 6952    no internet service
# 6953                     no
# 6954                    yes
# 6955                    yes
# 6956    no internet service
# 6957                     no
# 6958                    yes
# 6959                     no
# 6960    no internet service
# 6961                     no
# 6962                     no
# 6963    no internet service
# 6964                     no
# 6965                    yes
# 6966                    yes
# 6967    no internet service
# 6968                     no
# 6969                     no
# 6970                     no
# 6971    no internet service
# 6972                     no
# 6973                     no
# 6974                     no
# 6975                     no
# 6976                    yes
# 6977                     no
# 6978                     no
# 6979                     no
# 6980                     no
# 6981    no internet service
# 6982    no internet service
# 6983                     no
# 6984                     no
# 6985    no internet service
# 6986    no internet service
# 6987    no internet service
# 6988                    yes
# 6989                     no
# 6990    no internet service
# 6991                     no
# 6992                    yes
# 6993    no internet service
# 6994    no internet service
# 6995                     no
# 6996                     no
# 6997                     no
# 6998                    yes
# 6999                     no
# 7000                     no
# 7001    no internet service
# 7002                     no
# 7003                     no
# 7004                     no
# 7005                     no
# 7006                     no
# 7007                    yes
# 7008    no internet service
# 7009                    yes
# 7010                     no
# 7011    no internet service
# 7012    no internet service
# 7013                    yes
# 7014                    yes
# 7015                    yes
# 7016                    yes
# 7017                     no
# 7018                    yes
# 7019    no internet service
# 7020                     no
# 7021                     no
# 7022                     no
# 7023    no internet service
# 7024                    yes
# 7025                    yes
# 7026                    yes
# 7027                     no
# 7028                    yes
# 7029                    yes
# 7030                     no
# 7031    no internet service
# 7032                     no
# 7033                     no
# 7034                     no
# 7035                    yes
# 7036                    yes
# 7037                     no
# 7038                    yes
# 7039                     no
# 7040                    yes
# 7041                     no
# 7042    no internet service
# 7043                     no
# 7044                     no
# 7045                     no
# 7046                    yes
# 7047                     no
# 7048    no internet service
# 7049    no internet service
# 7050    no internet service
# 7051                    yes
# 7052                     no
# 7053                    yes
# 7054                    yes
# 7055                    yes
# 7056    no internet service
# 7057                     no
# 7058    no internet service
# 7059                    yes
# 7060                     no
# 7061                     no
# 7062                     no
# 7063                     no
# 7064                     no
# 7065                    yes
# 7066                     no
# 7067                    yes
# 7068    no internet service
# 7069                     no
# 7070                     no
# 7071                     no
# 7072                    yes
# 7073                     no
# 7074                    yes
# 7075                     no
# 7076                    yes
# 7077    no internet service
# 7078                    yes
# 7079                     no
# 7080                    yes
# 7081                     no
# 7082    no internet service
# 7083                    yes
# 7084                    yes
# 7085                     no
# 7086                     no
# 7087                     no
# 7088                    yes
# 7089                    yes
# 7090    no internet service
# 7091    no internet service
# 7092                     no
# 7093                    yes
# 7094                    yes
# 7095    no internet service
# 7096                     no
# 7097                     no
# 7098                    yes
# 7099                     no
# 7100                    yes
# 7101                     no
# 7102                    yes
# 7103                     no
# 7104                    yes
# 7105                    yes
# 7106                    yes
# 7107                    yes
# 7108                     no
# 7109                    yes
# 7110    no internet service
# 7111                     no
# 7112                    yes
# 7113                    yes
# 7114                     no
# 7115                     no
# 7116                    yes
# 7117                     no
# 7118    no internet service
# 7119                     no
# 7120                     no
# 7121    no internet service
# 7122                     no
# 7123    no internet service
# 7124                    yes
# 7125                    yes
# 7126                     no
# 7127    no internet service
# 7128                     no
# 7129                     no
# 7130    no internet service
# 7131    no internet service
# 7132    no internet service
# 7133                     no
# 7134                    yes
# 7135                     no
# 7136                     no
# 7137                    yes
# 7138                     no
# 7139                    yes
# 7140                    yes
# 7141                     no
# 7142    no internet service
# 7143    no internet service
# 7144                     no
# 7145                     no
# 7146                    yes
# 7147                    yes
# 7148                     no
# 7149                    yes
# 7150                     no
# 7151                     no
# 7152    no internet service
# 7153    no internet service
# 7154                    yes
# 7155                    yes
# 7156                     no
# 7157                     no
# 7158                     no
# 7159                    yes
# 7160                     no
# 7161                     no
# 7162    no internet service
# 7163                     no
# 7164    no internet service
# 7165                     no
# 7166                     no
# 7167                    yes
# 7168                     no
# 7169                     no
# 7170    no internet service
# 7171                     no
# 7172                     no
# 7173                     no
# 7174                    yes
# 7175                     no
# 7176    no internet service
# 7177    no internet service
# 7178                    yes
# 7179                    yes
# 7180                    yes
# 7181                     no
# 7182                    yes
# 7183                     no
# 7184                     no
# 7185                     no
# 7186                     no
# 7187                     no
# 7188                    yes
# 7189                    yes
# 7190                    yes
# 7191    no internet service
# 7192                     no
# 7193                     no
# 7194                     no
# 7195                    yes
# 7196                     no
# 7197                     no
# 7198                     no
# 7199                     no
# 7200                     no
# 7201                     no
# 7202                    yes
# 7203                     no
# 7204                     no
# 7205                     no
# 7206    no internet service
# 7207                    yes
# 7208                    yes
# 7209                     no
# 7210                     no
# 7211                     no
# 7212                    yes
# 7213                     no
# 7214                     no
# 7215                    yes
# 7216                     no
# 7217                    yes
# 7218                    yes
# 7219    no internet service
# 7220                     no
# 7221                    yes
# 7222    no internet service
# 7223                    yes
# 7224                    yes
# 7225    no internet service
# 7226                    yes
# 7227                     no
# 7228                    yes
# 7229                     no
# 7230                     no
# 7231                     no
# 7232                     no
# 7233    no internet service
# 7234                     no
# 7235                    yes
# 7236    no internet service
# 7237    no internet service
# 7238                     no
# 7239    no internet service
# 7240                     no
# 7241                    yes
# 7242                    yes
# 7243                     no
# 7244    no internet service
# 7245    no internet service
# 7246                     no
# 7247    no internet service
# 7248    no internet service
# 7249                    yes
# 7250    no internet service
# 7251                     no
# 7252    no internet service
# 7253                     no
# 7254                     no
# 7255                     no
# 7256    no internet service
# 7257    no internet service
# 7258                     no
# 7259                     no
# 7260                     no
# 7261    no internet service
# 7262                    yes
# 7263                     no
# 7264                     no
# 7265                    yes
# 7266                    yes
# Name: OnlineSecurity, dtype: object>

# %%
#Observando las variables de los datos usando .unique
print(datos_transformados['OnlineBackup'].unique())
print(datos_transformados['StreamingTV'].unique())
print(datos_transformados['StreamingMovies'].unique())
print(datos_transformados['Contract'].unique())
print(datos_transformados['PaperlessBilling'].unique())
print(datos_transformados['PaymentMethod'].unique())
# Out:
# ['yes' 'no' 'no internet service']
# ['yes' 'no' 'no internet service']
# ['no' 'yes' 'no internet service']
# ['one year' 'month-to-month' 'two year']
# ['yes' 'no']
# ['mailed check' 'electronic check' 'credit card (automatic)'
#  'bank transfer (automatic)']

# %% [markdown]
# ##Estandarización de los datos: traducirlas al español y ajustar sus variables

# %%
#1. Renombrar columnas para que estén en español
nuevos_nombres = {
    'customerID': 'ID Cliente',
    'Churn': 'Tasa de Abandono (Churn)',
    'gender': 'Género',
    'SeniorCitizen': 'Adulto Mayor',
    'Partner': 'Tiene Pareja',
    'Dependents': 'Tiene Dependientes',
    'tenure': 'Meses de Contrato',
    'PhoneService': 'Servicio Telefónico',
    'MultipleLines': 'Múltiples Líneas',
    'InternetService': 'Tipo de Internet',
    'OnlineSecurity': 'Seguridad en Línea',
    'OnlineBackup': 'Respaldo en Línea',
    'DeviceProtection': 'Protección del Equipo',
    'TechSupport': 'Soporte Técnico',
    'StreamingTV': 'TV Streaming',
    'StreamingMovies': 'Películas Streaming',
    'Contract': 'Tipo de Contrato',
    'PaperlessBilling': 'Facturación en Línea',
    'PaymentMethod': 'Método de Pago',
    'Charges_Monthly': 'Cargo Mensual',
    'Charges_Total': 'Cargo Total',
    'Cuentas_Diarias': 'Cargo Diario'

}
datos_transformados.rename(columns=nuevos_nombres, inplace=True)

#4. Vista previa de los cambios
datos_transformados.head(6)
# Out:
#    ID Cliente Tasa de Abandono (Churn)  Género  Adulto Mayor Tiene Pareja  \
# 0  0002-orfbo                       no  female             0          yes
# 1  0003-mknfe                       no    male             0           no
# 2  0004-tlhlj                      yes    male             0           no
# 3  0011-igkff                      yes    male             1          yes
# 4  0013-exchz                      yes  female             1          yes
# 5  0013-mhzwf                       no  female             0           no
#
#   Tiene Dependientes  Meses de Contrato Servicio Telefónico Múltiples Líneas  \
# 0                yes                  9                 yes               no
# 1                 no                  9                 yes              yes
# 2                 no                  4                 yes               no
# 3                 no                 13                 yes               no
# 4                 no                  3                 yes               no
# 5                yes                  9                 yes               no
#
#   Tipo de Internet Seguridad en Línea Respaldo en Línea Protección del Equipo  \
# 0              dsl                 no               yes                    no
# 1              dsl                 no                no                    no
# 2      fiber optic                 no                no                   yes
# 3      fiber optic                 no               yes                   yes
# 4      fiber optic                 no                no                    no
# 5              dsl                 no                no                    no
#
#   Soporte Técnico TV Streaming Películas Streaming Tipo de Contrato  \
# 0             yes          yes                  no         one year
# 1              no           no                 yes   month-to-month
# 2              no           no                  no   month-to-month
# 3              no          yes                 yes   month-to-month
# 4             yes          yes                  no   month-to-month
# 5             yes          yes                 yes   month-to-month
#
#   Facturación en Línea           Método de Pago  Cargo Mensual  Cargo Total  \
# 0                  yes             mailed check           65.6       593.30
# 1                   no             mailed check           59.9       542.40
# 2                  yes         electronic check           73.9       280.85
# 3                  yes         electronic check           98.0      1237.85
# 4                  yes             mailed check           83.9       267.40
# 5                  yes  credit card (automatic)           69.4       571.45
#
#    Cargo Diario
# 0          2.19
# 1          2.00
# 2          2.46
# 3          3.27
# 4          2.80
# 5          2.31

# %%
#Traducir y capitalizar Género
datos_transformados['Género'] = datos_transformados['Género'].map({
    'female': 'Femenino',
    'male': 'Masculino'
})

# %%
#Lista de columnas para inspeccionar
columnas_a_revisar = [
    'ID Cliente', 'Tasa de Abandono (Churn)', 'Género', 'Adulto Mayor', 'Tiene Pareja', 'Tiene Dependientes',
    'Servicio Telefónico', 'Múltiples Líneas', 'Tipo de Internet', 'Seguridad en Línea',
    'Respaldo en Línea', 'Protección del Equipo', 'Soporte Técnico', 'TV Streaming',
    'Películas Streaming', 'Tipo de Contrato', 'Facturación en Línea', 'Método de Pago',
]

#Mostrar valores únicos para cada columna, ordenadamente
for col in columnas_a_revisar:
    valores_unicos = datos_transformados[col].unique()
    print(f"Columna: {col}")
    print(f"Valores únicos ({len(valores_unicos)}): {valores_unicos}\n")
# Out:
# Columna: ID Cliente
# Valores únicos (7267): ['0002-orfbo' '0003-mknfe' '0004-tlhlj' ... '9992-ujoel' '9993-lhieb'
#  '9995-hotoh']
#
# Columna: Tasa de Abandono (Churn)
# Valores únicos (3): ['no' 'yes' '']
#
# Columna: Género
# Valores únicos (2): ['Femenino' 'Masculino']
#
# Columna: Adulto Mayor
# Valores únicos (2): [0 1]
#
# Columna: Tiene Pareja
# Valores únicos (2): ['yes' 'no']
#
# Columna: Tiene Dependientes
# Valores únicos (2): ['yes' 'no']
#
# Columna: Servicio Telefónico
# Valores únicos (2): ['yes' 'no']
#
# Columna: Múltiples Líneas
# Valores únicos (3): ['no' 'yes' 'no phone service']
#
# Columna: Tipo de Internet
# Valores únicos (3): ['dsl' 'fiber optic' 'no']
#
# Columna: Seguridad en Línea
# Valores únicos (3): ['no' 'yes' 'no internet service']
#
# Columna: Respaldo en Línea
# Valores únicos (3): ['yes' 'no' 'no internet service']
#
# Columna: Protección del Equipo
# Valores únicos (3): ['no' 'yes' 'no internet service']
#
# Columna: Soporte Técnico
# Valores únicos (3): ['yes' 'no' 'no internet service']
#
# Columna: TV Streaming
# Valores únicos (3): ['yes' 'no' 'no internet service']
#
# Columna: Películas Streaming
# Valores únicos (3): ['no' 'yes' 'no internet service']
#
# Columna: Tipo de Contrato
# Valores únicos (3): ['one year' 'month-to-month' 'two year']
#
# Columna: Facturación en Línea
# Valores únicos (2): ['yes' 'no']
#
# Columna: Método de Pago
# Valores únicos (4): ['mailed check' 'electronic check' 'credit card (automatic)'
#  'bank transfer (automatic)']

# %% [markdown]
# ##Ajustando la columna de adulto mayor

# %%
#Ajustar la columna de Adulto Mayor para que sea object y acepte valores númericos
datos_transformados['Adulto Mayor'] = datos_transformados['Adulto Mayor'].map({0: 'No', 1: 'Sí'})

# %%
#Lista con las columnas binarias que queremos mapear
binarias = [
    'Tiene Pareja',
    'Tiene Dependientes',
    'Servicio Telefónico',
    'Facturación en Línea',
]

for col in binarias:
    if col in datos_transformados.columns:
        datos_transformados[col] = datos_transformados[col].map({'yes': 'Sí', 'no': 'No'})

# %%
#Vista previa de los cambios
datos_transformados.head(6)
# Out:
#    ID Cliente Tasa de Abandono (Churn)     Género Adulto Mayor Tiene Pareja  \
# 0  0002-orfbo                       no   Femenino           No           Sí
# 1  0003-mknfe                       no  Masculino           No           No
# 2  0004-tlhlj                      yes  Masculino           No           No
# 3  0011-igkff                      yes  Masculino           Sí           Sí
# 4  0013-exchz                      yes   Femenino           Sí           Sí
# 5  0013-mhzwf                       no   Femenino           No           No
#
#   Tiene Dependientes  Meses de Contrato Servicio Telefónico Múltiples Líneas  \
# 0                 Sí                  9                  Sí               no
# 1                 No                  9                  Sí              yes
# 2                 No                  4                  Sí               no
# 3                 No                 13                  Sí               no
# 4                 No                  3                  Sí               no
# 5                 Sí                  9                  Sí               no
#
#   Tipo de Internet Seguridad en Línea Respaldo en Línea Protección del Equipo  \
# 0              dsl                 no               yes                    no
# 1              dsl                 no                no                    no
# 2      fiber optic                 no                no                   yes
# 3      fiber optic                 no               yes                   yes
# 4      fiber optic                 no                no                    no
# 5              dsl                 no                no                    no
#
#   Soporte Técnico TV Streaming Películas Streaming Tipo de Contrato  \
# 0             yes          yes                  no         one year
# 1              no           no                 yes   month-to-month
# 2              no           no                  no   month-to-month
# 3              no          yes                 yes   month-to-month
# 4             yes          yes                  no   month-to-month
# 5             yes          yes                 yes   month-to-month
#
#   Facturación en Línea           Método de Pago  Cargo Mensual  Cargo Total  \
# 0                   Sí             mailed check           65.6       593.30
# 1                   No             mailed check           59.9       542.40
# 2                   Sí         electronic check           73.9       280.85
# 3                   Sí         electronic check           98.0      1237.85
# 4                   Sí             mailed check           83.9       267.40
# 5                   Sí  credit card (automatic)           69.4       571.45
#
#    Cargo Diario
# 0          2.19
# 1          2.00
# 2          2.46
# 3          3.27
# 4          2.80
# 5          2.31

# %%
#Revisar si quedan valores nulos
print("\nValores nulos después de la limpieza:")
print(datos_transformados.isnull().sum())
# Out:
# Valores nulos después de la limpieza:
# ID Cliente                  0
# Tasa de Abandono (Churn)    0
# Género                      0
# Adulto Mayor                0
# Tiene Pareja                0
# Tiene Dependientes          0
# Meses de Contrato           0
# Servicio Telefónico         0
# Múltiples Líneas            0
# Tipo de Internet            0
# Seguridad en Línea          0
# Respaldo en Línea           0
# Protección del Equipo       0
# Soporte Técnico             0
# TV Streaming                0
# Películas Streaming         0
# Tipo de Contrato            0
# Facturación en Línea        0
# Método de Pago              0
# Cargo Mensual               0
# Cargo Total                 0
# Cargo Diario                0
# dtype: int64

# %% [markdown]
# ##Ajustando la columna de tasa de abandono (churn)

# %%
#Definir función para mapear y traducir valores
def mapear_churn(valor):
    if pd.isna(valor) or valor == '':
        #Consideramos vacíos o nulos como 'No' (cliente no abandonó)
        return 'No'
    valor = str(valor).strip().lower()
    if valor == 'yes':
        return 'Sí'
    elif valor == 'no':
        return 'No'
    else:
        #Por si hay valores inesperados, los consideramos como 'No'
        return 'No'

#Aplicar la función a la columna
datos_transformados['Tasa de Abandono (Churn)'] = datos_transformados['Tasa de Abandono (Churn)'].apply(mapear_churn)

# %%
#Vista previa de los cambios
datos_transformados.head(6)
# Out:
#    ID Cliente Tasa de Abandono (Churn)     Género Adulto Mayor Tiene Pareja  \
# 0  0002-orfbo                       No   Femenino           No           Sí
# 1  0003-mknfe                       No  Masculino           No           No
# 2  0004-tlhlj                       Sí  Masculino           No           No
# 3  0011-igkff                       Sí  Masculino           Sí           Sí
# 4  0013-exchz                       Sí   Femenino           Sí           Sí
# 5  0013-mhzwf                       No   Femenino           No           No
#
#   Tiene Dependientes  Meses de Contrato Servicio Telefónico Múltiples Líneas  \
# 0                 Sí                  9                  Sí               no
# 1                 No                  9                  Sí              yes
# 2                 No                  4                  Sí               no
# 3                 No                 13                  Sí               no
# 4                 No                  3                  Sí               no
# 5                 Sí                  9                  Sí               no
#
#   Tipo de Internet Seguridad en Línea Respaldo en Línea Protección del Equipo  \
# 0              dsl                 no               yes                    no
# 1              dsl                 no                no                    no
# 2      fiber optic                 no                no                   yes
# 3      fiber optic                 no               yes                   yes
# 4      fiber optic                 no                no                    no
# 5              dsl                 no                no                    no
#
#   Soporte Técnico TV Streaming Películas Streaming Tipo de Contrato  \
# 0             yes          yes                  no         one year
# 1              no           no                 yes   month-to-month
# 2              no           no                  no   month-to-month
# 3              no          yes                 yes   month-to-month
# 4             yes          yes                  no   month-to-month
# 5             yes          yes                 yes   month-to-month
#
#   Facturación en Línea           Método de Pago  Cargo Mensual  Cargo Total  \
# 0                   Sí             mailed check           65.6       593.30
# 1                   No             mailed check           59.9       542.40
# 2                   Sí         electronic check           73.9       280.85
# 3                   Sí         electronic check           98.0      1237.85
# 4                   Sí             mailed check           83.9       267.40
# 5                   Sí  credit card (automatic)           69.4       571.45
#
#    Cargo Diario
# 0          2.19
# 1          2.00
# 2          2.46
# 3          3.27
# 4          2.80
# 5          2.31

# %%
#Revisar si quedan valores nulos
print("\nValores nulos después de la limpieza:")
print(datos_transformados.isnull().sum())
# Out:
# Valores nulos después de la limpieza:
# ID Cliente                  0
# Tasa de Abandono (Churn)    0
# Género                      0
# Adulto Mayor                0
# Tiene Pareja                0
# Tiene Dependientes          0
# Meses de Contrato           0
# Servicio Telefónico         0
# Múltiples Líneas            0
# Tipo de Internet            0
# Seguridad en Línea          0
# Respaldo en Línea           0
# Protección del Equipo       0
# Soporte Técnico             0
# TV Streaming                0
# Películas Streaming         0
# Tipo de Contrato            0
# Facturación en Línea        0
# Método de Pago              0
# Cargo Mensual               0
# Cargo Total                 0
# Cargo Diario                0
# dtype: int64

# %%
#Mostrar valores únicos para cada columna, ordenadamente
for col in columnas_a_revisar:
    valores_unicos = datos_transformados[col].unique()
    print(f"Columna: {col}")
    print(f"Valores únicos ({len(valores_unicos)}): {valores_unicos}\n")
# Out:
# Columna: ID Cliente
# Valores únicos (7267): ['0002-orfbo' '0003-mknfe' '0004-tlhlj' ... '9992-ujoel' '9993-lhieb'
#  '9995-hotoh']
#
# Columna: Tasa de Abandono (Churn)
# Valores únicos (2): ['No' 'Sí']
#
# Columna: Género
# Valores únicos (2): ['Femenino' 'Masculino']
#
# Columna: Adulto Mayor
# Valores únicos (2): ['No' 'Sí']
#
# Columna: Tiene Pareja
# Valores únicos (2): ['Sí' 'No']
#
# Columna: Tiene Dependientes
# Valores únicos (2): ['Sí' 'No']
#
# Columna: Servicio Telefónico
# Valores únicos (2): ['Sí' 'No']
#
# Columna: Múltiples Líneas
# Valores únicos (3): ['no' 'yes' 'no phone service']
#
# Columna: Tipo de Internet
# Valores únicos (3): ['dsl' 'fiber optic' 'no']
#
# Columna: Seguridad en Línea
# Valores únicos (3): ['no' 'yes' 'no internet service']
#
# Columna: Respaldo en Línea
# Valores únicos (3): ['yes' 'no' 'no internet service']
#
# Columna: Protección del Equipo
# Valores únicos (3): ['no' 'yes' 'no internet service']
#
# Columna: Soporte Técnico
# Valores únicos (3): ['yes' 'no' 'no internet service']
#
# Columna: TV Streaming
# Valores únicos (3): ['yes' 'no' 'no internet service']
#
# Columna: Películas Streaming
# Valores únicos (3): ['no' 'yes' 'no internet service']
#
# Columna: Tipo de Contrato
# Valores únicos (3): ['one year' 'month-to-month' 'two year']
#
# Columna: Facturación en Línea
# Valores únicos (2): ['Sí' 'No']
#
# Columna: Método de Pago
# Valores únicos (4): ['mailed check' 'electronic check' 'credit card (automatic)'
#  'bank transfer (automatic)']

# %% [markdown]
# ##Transformaciones de las columnas con datos aún no cambiados

# %%
#Diccionarios de traducción para los valores
map_si_no = {'yes': 'Sí', 'no': 'No'}
map_no_service_phone = {'no phone service': 'Sin servicio telefónico'}
map_no_service_internet = {'no internet service': 'Sin servicio de internet'}

#Columnas con valores 'yes'/'no' que faltan traducir
columnas_si_no = [
    'Múltiples Líneas',
    'Seguridad en Línea',
    'Respaldo en Línea',
    'Protección del Equipo',
    'Soporte Técnico',
    'TV Streaming',
    'Películas Streaming'
]

#Traducir valores en columnas binarias con 'yes'/'no'
for col in columnas_si_no:
    if col in datos_transformados.columns:
        datos_transformados[col] = datos_transformados[col].map(lambda x: map_si_no.get(x, x))

#Traducir valores 'no phone service' en 'Múltiples Líneas'
if 'Múltiples Líneas' in datos_transformados.columns:
    datos_transformados['Múltiples Líneas'] = datos_transformados['Múltiples Líneas'].replace(map_no_service_phone)

#Traducir valores 'no internet service' en las columnas relacionadas con internet
cols_no_internet_service = [
    'Seguridad en Línea',
    'Respaldo en Línea',
    'Protección del Equipo',
    'Soporte Técnico',
    'TV Streaming',
    'Películas Streaming'
]

for col in cols_no_internet_service:
    if col in datos_transformados.columns:
        datos_transformados[col] = datos_transformados[col].replace(map_no_service_internet)

#Traducir valores de 'Tipo de Contrato'
map_tipo_contrato = {
    'one year': 'Un año',
    'month-to-month': 'Mes a mes',
    'two year': 'Dos años'
}

if 'Tipo de Contrato' in datos_transformados.columns:
    datos_transformados['Tipo de Contrato'] = datos_transformados['Tipo de Contrato'].map(map_tipo_contrato)

#Traducir valores de 'Método de Pago'
map_metodo_pago = {
    'mailed check': 'Cheque enviado por correo',
    'electronic check': 'Cheque electrónico',
    'credit card (automatic)': 'Tarjeta de crédito (automático)',
    'bank transfer (automatic)': 'Transferencia bancaria (automático)'
}

if 'Método de Pago' in datos_transformados.columns:
    datos_transformados['Método de Pago'] = datos_transformados['Método de Pago'].map(map_metodo_pago)

#Traducir valores de 'Tipo de Internet'
map_tipo_internet = {
    'dsl': 'DSL',
    'fiber optic': 'Fibra Óptica',
    'no': 'Sin Servicio'
}

if 'Tipo de Internet' in datos_transformados.columns:
    datos_transformados['Tipo de Internet'] = datos_transformados['Tipo de Internet'].map(map_tipo_internet)

# %%
#Verificar resultados
cols_a_verificar = columnas_si_no + ['Múltiples Líneas', 'Tipo de Contrato', 'Método de Pago', 'Tipo de Internet']
for col in cols_a_verificar:
    if col in datos_transformados.columns:
        print(f"{col}: {datos_transformados[col].unique()}")
# Out:
# Múltiples Líneas: ['No' 'Sí' 'Sin servicio telefónico']
# Seguridad en Línea: ['No' 'Sí' 'Sin servicio de internet']
# Respaldo en Línea: ['Sí' 'No' 'Sin servicio de internet']
# Protección del Equipo: ['No' 'Sí' 'Sin servicio de internet']
# Soporte Técnico: ['Sí' 'No' 'Sin servicio de internet']
# TV Streaming: ['Sí' 'No' 'Sin servicio de internet']
# Películas Streaming: ['No' 'Sí' 'Sin servicio de internet']
# Múltiples Líneas: ['No' 'Sí' 'Sin servicio telefónico']
# Tipo de Contrato: ['Un año' 'Mes a mes' 'Dos años']
# Método de Pago: ['Cheque enviado por correo' 'Cheque electrónico'
#  'Tarjeta de crédito (automático)' 'Transferencia bancaria (automático)']
# Tipo de Internet: ['DSL' 'Fibra Óptica' 'Sin Servicio']

# %%
#Vista previa de los cambios
datos_transformados.head(6)
# Out:
#    ID Cliente Tasa de Abandono (Churn)     Género Adulto Mayor Tiene Pareja  \
# 0  0002-orfbo                       No   Femenino           No           Sí
# 1  0003-mknfe                       No  Masculino           No           No
# 2  0004-tlhlj                       Sí  Masculino           No           No
# 3  0011-igkff                       Sí  Masculino           Sí           Sí
# 4  0013-exchz                       Sí   Femenino           Sí           Sí
# 5  0013-mhzwf                       No   Femenino           No           No
#
#   Tiene Dependientes  Meses de Contrato Servicio Telefónico Múltiples Líneas  \
# 0                 Sí                  9                  Sí               No
# 1                 No                  9                  Sí               Sí
# 2                 No                  4                  Sí               No
# 3                 No                 13                  Sí               No
# 4                 No                  3                  Sí               No
# 5                 Sí                  9                  Sí               No
#
#   Tipo de Internet Seguridad en Línea Respaldo en Línea Protección del Equipo  \
# 0              DSL                 No                Sí                    No
# 1              DSL                 No                No                    No
# 2     Fibra Óptica                 No                No                    Sí
# 3     Fibra Óptica                 No                Sí                    Sí
# 4     Fibra Óptica                 No                No                    No
# 5              DSL                 No                No                    No
#
#   Soporte Técnico TV Streaming Películas Streaming Tipo de Contrato  \
# 0              Sí           Sí                  No           Un año
# 1              No           No                  Sí        Mes a mes
# 2              No           No                  No        Mes a mes
# 3              No           Sí                  Sí        Mes a mes
# 4              Sí           Sí                  No        Mes a mes
# 5              Sí           Sí                  Sí        Mes a mes
#
#   Facturación en Línea                   Método de Pago  Cargo Mensual  \
# 0                   Sí        Cheque enviado por correo           65.6
# 1                   No        Cheque enviado por correo           59.9
# 2                   Sí               Cheque electrónico           73.9
# 3                   Sí               Cheque electrónico           98.0
# 4                   Sí        Cheque enviado por correo           83.9
# 5                   Sí  Tarjeta de crédito (automático)           69.4
#
#    Cargo Total  Cargo Diario
# 0       593.30          2.19
# 1       542.40          2.00
# 2       280.85          2.46
# 3      1237.85          3.27
# 4       267.40          2.80
# 5       571.45          2.31

# %%
#Revisar si quedan valores nulos
print("\nValores nulos después de la limpieza:")
print(datos_transformados.isnull().sum())
# Out:
# Valores nulos después de la limpieza:
# ID Cliente                  0
# Tasa de Abandono (Churn)    0
# Género                      0
# Adulto Mayor                0
# Tiene Pareja                0
# Tiene Dependientes          0
# Meses de Contrato           0
# Servicio Telefónico         0
# Múltiples Líneas            0
# Tipo de Internet            0
# Seguridad en Línea          0
# Respaldo en Línea           0
# Protección del Equipo       0
# Soporte Técnico             0
# TV Streaming                0
# Películas Streaming         0
# Tipo de Contrato            0
# Facturación en Línea        0
# Método de Pago              0
# Cargo Mensual               0
# Cargo Total                 0
# Cargo Diario                0
# dtype: int64

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# ##Análisis descriptivo

# %% [markdown]
# #📄Informe final
